# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import plotly_express as px

# import plotly as ply

data = pd.read_csv("https://raw.githubusercontent.com/AllanMisasaUCL/SoftwarekonstruktionE21/main/marketing_campaign.csv", sep='\t')
headers = data.columns.values.tolist()
data["Income"].dropna(inplace=True)

# %%
headers = data.columns.values.tolist()

# %%
valg = input('Vælg de data du gerne vil analysere: ')
filtered_choices = ''.join(filter(str.isdigit, valg))
plt.hist(data[headers[int(filtered_choices[0])-1]])

range(len(headers)) # Viser headers 0-29 = output range(0, 29)
for choice in range (len(headers)):
    print((choice+1), ': ', headers[choice])
# Out:
# Vælg de data du gerne vil analysere: 3
# 1 :  ID
# 2 :  Year_Birth
# 3 :  Education
# 4 :  Marital_Status
# 5 :  Income
# 6 :  Kidhome
# 7 :  Teenhome
# 8 :  Dt_Customer
# 9 :  Recency
# 10 :  MntWines
# 11 :  MntFruits
# 12 :  MntMeatProducts
# 13 :  MntFishProducts
# 14 :  MntSweetProducts
# 15 :  MntGoldProds
# 16 :  NumDealsPurchases
# 17 :  NumWebPurchases
# 18 :  NumCatalogPurchases
# 19 :  NumStorePurchases
# 20 :  NumWebVisitsMonth
# 21 :  AcceptedCmp3
# 22 :  AcceptedCmp4
# 23 :  AcceptedCmp5
# 24 :  AcceptedCmp1
# 25 :  AcceptedCmp2
# 26 :  Complain
# 27 :  Z_CostContact
# 28 :  Z_Revenue
# 29 :  Response

# %%
all_choices = []
valg = input('Vælg de data du gerne vil analysere: ')
filtered_choices = ''.join(filter(str.isdigit, valg))

for choice in range (len(filtered_choices)):
    all_choices.append(data[headers[int(filtered_choices[choice])-1]])
# Out:
# Vælg de data du gerne vil analysere: 23

# %%
#fig(betyder figure), ax (ax definerer vi som subplot) = plt.subplots (funktionen subplot)
#(1, 4,(betyder 2= to rækker og 2 = 2 kolonner)  figsize=(20, 4) (20 = bredde og 4 = længde på grafen)

#rækker og kolonner bliver defineret sådan
#[(0,0)(0,1)]
#[(1,0)(1,1)]

#ax[0,0].plot(all_choices[0])


fig, ax = plt.subplots(2, 2, figsize=(20, 10)) 
ax[0,0].plot(all_choices[0])
ax[1,0].hist(all_choices[1])
ax[0,1].plot(all_choices[2])
ax[1,1].plot(all_choices[3])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-42dc0a006127> in <module>
#      12 ax[0,0].plot(all_choices[0])
#      13 ax[1,0].hist(all_choices[1])
# ---> 14 ax[0,1].plot(all_choices[2])
#      15 ax[1,1].plot(all_choices[3])
#      16
#
# IndexError: list index out of range

# %%
plottypes = ['Line plot', 'Histogram', 'Pie chart', 'Scatter plot', 'Bar chart']

# %%
print(plottypes)
# Out:
# ['Line plot', 'Histogram', 'Pie chart', 'Scatter plot', 'Bar chart']

# %%
for choice in range (len(headers)):
    print((choice+1), ': ', headers[choice])                         


    
all_choices = []
valg = input('Vælg de data du gerne vil analysere: ')
filtered_choices = ''.join(filter(str.isdigit, valg))

for choice in range (len(filtered_choices)):
    all_choices.append(data[headers[int(filtered_choices[choice])-1]])
    
for n in range (len(plottypes)):
    print((n+1), ': ', plottypes[n])
    
valggraf = input('Vælg graf at analysere: ')

#d    
def multiplot(lol): #liste af en liste
    if len(lol)==1:
        plt.plot(lol)
        plt.show()
        
    if len(lol)==2:
        fig, ax = plt.subplots(1, 2, figsize=(9, 3)) 
        ax[0].plot(lol[0])
        ax[1].hist(lol[1])
        plt.show()
        
    if len(lol)==3:
        fig, ax = plt.subplots(1, 3, figsize=(16, 6)) 
        ax[0].plot(lol[0])
        ax[1].hist(lol[1])
        ax[2].scatter(all_choices[1],all_choices[2])
        plt.show()
        
    if len(lol)==4:
        fig, ax = plt.subplots(2, 2, figsize=(20, 10)) 
        ax[0,0].plot(lol[0])
        ax[1,0].hist(lol[1])
        ax[0,1].plot(lol[2])
        ax[1,1].plot(lol[3])
        plt.show()
        
multiplot(all_choices)
# Out:
# 1 :  ID
# 2 :  Year_Birth
# 3 :  Education
# 4 :  Marital_Status
# 5 :  Income
# 6 :  Kidhome
# 7 :  Teenhome
# 8 :  Dt_Customer
# 9 :  Recency
# 10 :  MntWines
# 11 :  MntFruits
# 12 :  MntMeatProducts
# 13 :  MntFishProducts
# 14 :  MntSweetProducts
# 15 :  MntGoldProds
# 16 :  NumDealsPurchases
# 17 :  NumWebPurchases
# 18 :  NumCatalogPurchases
# 19 :  NumStorePurchases
# 20 :  NumWebVisitsMonth
# 21 :  AcceptedCmp3
# 22 :  AcceptedCmp4
# 23 :  AcceptedCmp5
# 24 :  AcceptedCmp1
# 25 :  AcceptedCmp2
# 26 :  Complain
# 27 :  Z_CostContact
# 28 :  Z_Revenue
# 29 :  Response
# Vælg de data du gerne vil analysere: 357
# 1 :  Line plot
# 2 :  Histogram
# 3 :  Pie chart
# 4 :  Scatter plot
# 5 :  Bar chart
# Vælg graf at analysere: 233

# %%
data.columns[10]
# Out:
# 'MntFruits'

# %%
data['TotalForbrug']=np.sum(data[data.columns[9:15]].T)

# %%
px.bar(data, x='Education', y='TotalForbrug')
# Out:
# <div>
#
#
#             <div id="ad9af020-7cf3-4042-b4e2-c8c15d5de23b" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ad9af020-7cf3-4042-b4e2-c8c15d5de23b")) {
#                     Plotly.newPlot(
#                         'ad9af020-7cf3-4042-b4e2-c8c15d5de23b',
# ...
